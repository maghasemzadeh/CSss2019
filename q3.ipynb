# %%
import pandas as pd
from modules import *
happiness = pd.read_csv('datasets/HappinessScore.csv')
t1 = pd.read_csv('datasets/Engineering-Mozzarella.csv')
t2 = pd.read_csv('datasets/Hanging-US Spending.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-651dc76f58f2> in <module>
#       1 import pandas as pd
# ----> 2 from modules import *
#       3 happiness = pd.read_csv('datasets/HappinessScore.csv')
#       4 t1 = pd.read_csv('datasets/Engineering-Mozzarella.csv')
#       5 t2 = pd.read_csv('datasets/Hanging-US Spending.csv')
#
# ModuleNotFoundError: No module named 'modules'

# %% [markdown]
# <div style="direction:rtl;line-height:300%;"><font face="IRANSans" size=5>
# <font color=red size=7>
# <p></p>
# <div align=center>بخش ۳ </div>
# </font></div>
# <hr/>

# %%
import io
import base64
from IPython.display import HTML

video = io.open('datasets/Visualization.mp4', 'r+b').read()
encoded = base64.b64encode(video)
HTML(data='''<video alt="test" autoplay muted loop>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii')))
# Out:
# <video alt="test" autoplay muted loop>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# <div style="direction:rtl;line-height:110%;"><font face="IRANSans" size=3>
#     شما از فیلم بالا چه برداشتی دارید؟ :)
# </font></div>

# %% [markdown]
# <div style="direction:rtl;line-height:200%;"><font face="IRANSans" size=3>
#     دیتاست مربوط به رفاه جهانی به شما داده شده است. به کمک دستور
#     <code>head</code>
#     چندتا از داده‌های این دیتاست را مشاهده کنید.
# <br/><br/>
# ستون‌های این دیتاست این‌ها هستند:
# <br/>
#
#   <lu>
#     Country:کشور
#     </lu>
#     <br>
#     <lu>
#     Happiness Score: میزان شادی
#     </lu>
#     <br>
#     <lu>
#     GDP per Capita: تولید داخلی به نسبت جمعیت
#     </lu>
#     <br>
#     <lu>
#     Social Progress Index: شاخص پیشرفت اجتماعی
#     </lu>
#     <br>
#     <lu>
#     Basic Human Needs: نیازهای اولیه‌ی انسانی
#     </lu>
#     <br>
#     <lu>
#     Water and Sanitation: آب و بهداشت
#     </lu>
#     <br>
#     <lu>
#     Shelter: سرپناه
#     </lu>
#     <br>
#     <lu>
#     Personal Rights: حقوق شهروندی
#     </lu>
#     <br>
#     <lu>
#     Access to Advanced Education:دسترسی به تحصیلات عالی
#     </lu>
# </font></div>

# %%
head(happiness)
# Out:
#        Country  Happiness Score  GDP per Capita  Social Progress Index  \
# 0  Afghanistan            3.794           0.401                  35.66
# 1      Albania            4.644           0.996                  70.97
# 2      Algeria            5.872           1.092                  65.41
# 3       Angola            3.795           0.858                  40.73
# 4    Argentina            6.599           1.185                  75.90
#
#    Basic Human Needs  Water and Sanitation  Shelter  Personal Rights  \
# 0              42.65                 29.33    22.92            37.40
# 1              85.53                 90.69    80.45            60.53
# 2              78.15                 81.23    70.58            36.21
# 3              44.37                 27.63    28.49            28.28
# 4              81.71                 98.32    67.25            67.51
#
#    Access to Advanced Education
# 0                          6.73
# 1                         32.16
# ...

# %% [markdown]
# <div style="direction:rtl;line-height:200%;"><font face="IRANSans" size=3>
#     رابطه متغیرهای زیر را با هم بررسی کنید. توضیحات خود را در جهت توجیه مشاهداتتان ارائه دهید.
#     <br><hr><br>
# ۱- دسترسی به تحصیلات عالی - شاخص پیشرفت اجتماعی
#
# </font></div>

# %% [markdown]
# <div style="direction:rtl;line-height:110%;"><font face="IRANSans" size=3>
#     ۲- تولید  داخلی بر حسب جمعیت - میزان شادی
# </font></div>

# %% [markdown]
# <div style="direction:rtl;line-height:110%;"><font face="IRANSans" size=3>
#     ۳- سرپناه - نیازهای اولیه انسانی
# </font></div>

# %% [markdown]
# <div style="direction:rtl;line-height:110%;"><font face="IRANSans" size=3>
#    ۴- آب و فاضلاب - سرپناه
# </font></div>

# %% [markdown]
# <div style="direction:rtl;line-height:110%;"><font face="IRANSans" size=3>
#    ۵- حقوق شهروندی - میزان شادی
# </font></div>

# %% [markdown]
# <div style="direction:rtl;line-height:150%;"><font face="IRANSans" size=3>
#   اکنون که با روابط بین متغیرها آشنا شده‌ایم، می‌خواهیم که روابط موجود بین چندمتغیر دیگر را شناسایی کنیم! نمودارهایی که در زیر می‌بینید، نمودار مربوط به دو دیتاست متفاوت است. همان‌طور که مشاهده‌ می‌کنید،‌روابط بین  دو متغیر موجود در هر نمودار خطی است. از شما می‌خواهیم دیتاست مربوط به هر نمودار را مشاهده کنید. این مشاهدات را چگونه توجیه می‌کنید؟:)
# </font></div>

# %%
plot_2d(t1, t1.columns[1], t1.columns[2])

# %%
plot_2d(t2, t2.columns[1], t2.columns[2])
