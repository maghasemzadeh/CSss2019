# %%
import pandas as pd
from src.hypothesis_test import *
from src.modules import *
import warnings
warnings.filterwarnings('ignore')
lung_cancer = pd.read_csv('data_sets/lung_cancer_examples.csv')

# %% [markdown]
# <div dir = "rtl" >
#     بخشی از دیتاست رو در زیر میتونید مشاهده کنید.
#     </div>

# %%
lung_cancer.head()
# Out:
#      Name      Surname  Age  Smokes  AreaQ  Alkhol  Result
# 0    John         Wick   35       3      5       4       1
# 1    John  Constantine   27      20      2       5       1
# 2  Camela     Anderson   30       0      5       2       0
# 3    Alex       Telles   28       0      8       1       0
# 4   Diego     Maradona   68       4      5       6       1

# %% [markdown]
# <div dir = "rtl" >
#     نمودار چگالی تعداد بار سیگار کشیدن را برای افراد بیمار در زیر مشاهده کنید.
#     </div>

# %%
density(lung_cancer, ['Smokes'], bin_size = 5, criteria='Result == 1')
# Out:
# <div>
#
#
#             <div id="49f10f23-b29b-4113-b413-bf1043b57245" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("49f10f23-b29b-4113-b413-bf1043b57245")) {
#                     Plotly.newPlot(
#                         '49f10f23-b29b-4113-b413-bf1043b57245',
# ...

# %% [markdown]
# <div dir = "rtl" >
#     نمودار چگالی تعداد بار سیگار کشیدن را برای افراد سالم در زیر مشاهده کنید.
#     <br>
#      با توجه به این دو نمودار چه فرض دارید؟
#     <div>

# %%
density(lung_cancer, ['Smokes'], bin_size = 5, criteria='Result == 0')
# Out:
# <div>
#
#
#             <div id="008c6fe6-4464-495d-a382-8245b3208b7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("008c6fe6-4464-495d-a382-8245b3208b7d")) {
#                     Plotly.newPlot(
#                         '008c6fe6-4464-495d-a382-8245b3208b7d',
# ...

# %% [markdown]
# <div dir = "rtl" >
#     با کمک منتورها، برای آزمون فرض خود از کل داده ها چند بار داده ها را به دو دسته تصادفی تقسیم کنید و میانگین آنها را بررسی کنید.
#     <br>
#      برای این کار از تابع random_grouping استفاده کنید.
#     </div>

# %%
random_grouping(lung_cancer, "Result", "Smokes")
# Out:
# <div>
#
#
#             <div id="a7453bec-d000-4fe9-a438-24ad6095d00b" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a7453bec-d000-4fe9-a438-24ad6095d00b")) {
#                     Plotly.newPlot(
#                         'a7453bec-d000-4fe9-a438-24ad6095d00b',
# ...

# %% [markdown]
# <div dir = "rtl">
#     حالا با کمک تابع permutation_test  نمودار کل اختلاف میانگین های دو دسته را رسم کنید.
#     </div>

# %%
permutation_test(lung_cancer, "Result", "Smokes")
# Out:
# C:\Users\mahsa\Anaconda3\lib\random.py:275: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# <div dir = "rtl">
# نمودار را تحلیل کنید.
# </div>
